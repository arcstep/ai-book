# %% [markdown]
# # 培训大纲
#
# ## 机器学习开发基础
#
# ### 什么是模型
# 举例子：拟合线性模型
#
# ### 什么是神经网络
# 举例子：拟合任何函数的三层神经网络
#
# 延伸：卷积神经网络，循环神经网络
#
# ### NumPy
# - 矩阵计算
#
# ### pyTorch
# - 张量计算
# - GPT计算（CUDA）
# - 神经网络计算框架
#
# ### HuggingFace
# - 自动数据
# - 自动模型（兼容PyTorch、Tensorflow）
#
# ### Langchain
# - 标准化组件
# - LCEL
#
# ## NLP和词向量
#
# ### 独热编码
# - 小型词表
#
# ### 词嵌入
# - 词编码
# - 词嵌入
#
# ### 句子嵌入
# - 句子编码
#
# ### 向量数据库
# - 句子嵌入
# - 图片嵌入
#
# ## BERT类模型
#
# ### 分类任务
# - 直接使用
# - 微调
#
# ### 知识蒸馏
# - TinyBERT
# - 分类任务微调
#
# ## GPT类模型
#
# ### 大模型比较
# - GPT4
# - GLM4
#
# ### 提示工程
# - 直接提问
# - 生成代码
# - 图片理解
# - 图片生成
# - 提示语指引
# - 小样本
# - 模板化
# - 历史记录
# - RAG
#
# ### 回调工具
# - Function-Calling / Tools-Calling
# - 回调工具工作流程：create_openai_tools_agent
#
# ### 智能体
#
#
# ### 模型微调
